# %% [markdown]
# # EXERCISE PANDAS

# %%
# importar pandas
import pandas as pd

# %%
# mostrar todas las filas del DF por defecto con pd.set_option()
pd.set_option()

# %% [markdown]
# # Crear un DataFrame

# %%
# leer el archivo csv "bestsellers with categories" (datos sobre los 50 libros más vendidos de Amazon de 2009 a 2019.)
df_books = pd.read_csv("bestsellers+with+categories.csv")

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# acceder al tributo shape
df_books.shape
# Out:
# (550, 7)

# %%
# mostrar todas las filas
pd.set_option('display.max_rows',550)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
# numero filas, inicio y fin
df_books.index
# Out:
# RangeIndex(start=0, stop=550, step=1)

# %%
#nombres de las columnas
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
# tipo de dato de cada columna
df_books.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
# informacion del dataframe / buscando non-null
df_books.info
# Out:
# <bound method DataFrame.info of                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# ...

# %% [markdown]
# # Mostrar un Dataframe

# %%
# mostrar primeras 5 filas del dataframe
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
 # estadisticas básicas del dataframe
df_books.describe().round(2)
# Out:
#        User Rating   Reviews   Price     Year
# count       550.00    550.00  550.00   550.00
# mean          4.62  11953.28   13.10  2014.00
# std           0.23  11731.13   10.84     3.17
# min           3.30     37.00    0.00  2009.00
# 25%           4.50   4058.00    7.00  2011.00
# 50%           4.70   8580.00   11.00  2014.00
# 75%           4.80  17253.25   16.00  2017.00
# max           4.90  87841.00  105.00  2019.00

# %% [markdown]
# # Agregar una nueva columnna

# %%
# crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4
df_books = pd.read_csv('bestsellers+with+categories.csv')
df_books
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4
# ----> 2 df_books = pd.read_csv('bestsellers+with+categories.csv')
#       3 df_books
#
# NameError: name 'pd' is not defined

# %%
import numpy as np

# %%
Critic_Rating = np.arange(0,550)
df_books['Critic Rating'] = Critic_Rating
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
int_Critic_Rating = np.random.randint(1, 4, size=550)
df_books['Critic Rating'] = int_Critic_Rating
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              1
# 1              3
# 2              3
# 3              1
# 4              2

# %% [markdown]
# # Atributos, Metodos y funciones

# %%
# acceder al atributo " Columns"
df_books['Critic Rating']
# Out:
# 0      1
# 1      3
# 2      3
# 3      1
# 4      2
# 5      1
# 6      1
# 7      2
# 8      2
# 9      1
# 10     3
# 11     3
# 12     3
# 13     3
# 14     3
# 15     1
# 16     3
# 17     3
# 18     1
# 19     2
# 20     3
# 21     1
# 22     2
# 23     1
# 24     1
# 25     3
# 26     2
# 27     1
# 28     2
# 29     3
# 30     3
# 31     3
# 32     3
# 33     3
# 34     2
# 35     3
# 36     3
# 37     1
# 38     1
# 39     2
# 40     3
# 41     2
# 42     1
# 43     1
# 44     2
# 45     3
# 46     3
# 47     2
# 48     3
# 49     1
# 50     1
# 51     2
# 52     1
# 53     3
# 54     1
# 55     3
# 56     3
# 57     2
# 58     1
# 59     1
# 60     1
# 61     2
# 62     1
# 63     3
# 64     1
# 65     1
# 66     1
# 67     1
# 68     3
# 69     2
# 70     2
# 71     3
# 72     1
# 73     1
# 74     3
# 75     3
# 76     3
# 77     2
# 78     1
# 79     1
# 80     1
# 81     3
# 82     1
# 83     2
# 84     1
# 85     2
# 86     3
# 87     2
# 88     1
# 89     1
# ...

# %% [markdown]
# # Seleccionar 2 o mas Columnas

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" 
df_books[['Name', 'Author', 'User Rating', 'Critic Rating', 'Reviews', 'Price', 'Year', 'Genre']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              1
# 1              3
# 2              3
# 3              1
# 4              2

# %% [markdown]
# # Operaciones con Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rat
df_books ['Average Rating'] = df_books['User Rating'].mean()
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
# usar la funcion "round" para redondear los valores del dataframe a 1 deci

# %%
df_books.round(1)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa

# %%
df_books['Genre'].count()
# Out:
# 550

# %%
len(df_books['Genre'])
# Out:
# 550

# %%
# Contar elementos "genre" por categoria
df_books['Genre'].value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %%
# obtener la frecuencia relativa (dividir todos los valores entre la suma de una categoria)
df_books['Genre'].value_counts(normalize=True)
# Out:
# Non Fiction    0.563636
# Fiction        0.436364
# Name: Genre, dtype: float64

# %% [markdown]
# # Renombrar columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
df_books.rename(columns={'User Rating': 'UR',
                         'Critic Rating': 'CR',
                         'Average Rating': 'AR'}, inplace=True)

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  Reviews  Price  Year        Genre  CR  \
# 0                    JJ Smith  4.7    17350      8  2016  Non Fiction   3
# 1                Stephen King  4.6     2052     22  2011      Fiction   2
# 2          Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   1
# ...

# %%
df_books.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  Reviews  Price  Year        Genre  CR  \
# 0                  JJ Smith  4.7    17350      8  2016  Non Fiction   1
# 1              Stephen King  4.6     2052     22  2011      Fiction   3
# 2        Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   3
# 3             George Orwell  4.7    21424      6  2017      Fiction   1
# 4  National Geographic Kids  4.8     7665     12  2019  Non Fiction   2
#
#          AR
# 0  4.618364
# 1  4.618364
# 2  4.618364
# 3  4.618364
# 4  4.618364

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 11   A Patriot's History of the United States: From...
# 12                             A Stolen Life: A Memoir
# 13                    A Wrinkle in Time (Time Quintet)
# 14   Act Like a Lady, Think Like a Man: What Men Re...
# 15   Adult Coloring Book Designs: Stress Relief Col...
# ...

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
df_books.sort_values(['UR','CR'], ascending=True,inplace=True)
df_books
# Out:
#                                                   Name  \
# 353                                 The Casual Vacancy
# 132                         Go Set a Watchman: A Novel
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...
# 393  The Goldfinch: A Novel (Pulitzer Prize for Fic...
# 22                                           Allegiant
# 135                                          Gone Girl
# 304                                StrengthsFinder 2.0
# 305                                StrengthsFinder 2.0
# 306                                StrengthsFinder 2.0
# 310                                StrengthsFinder 2.0
# 137                                          Gone Girl
# 154  Harry Potter and the Cursed Child, Parts 1 & 2...
# 307                                StrengthsFinder 2.0
# 308                                StrengthsFinder 2.0
# ...
